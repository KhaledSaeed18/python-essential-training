# %% [markdown]
# # Basic Data Types

# %% [markdown]
# ## Define a variable:

# %%
x = 5

# %%
print(x)
# Out:
# 5

# %%
x
# Out:
# 5

# %% [markdown]
# Variable names can't start with numbers

# %%
1x
# Out:
#   Cell In[5], line 1
#     1x
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# Variable names can't start with special characters, exeption: "_"

# %%
_a = 5

# %% [markdown]
# Check variable type using `type()`

# %%
type(x)
# Out:
# int

# %% [markdown]
# ### Numbers

# %%
type(1.5)
# Out:
# float

# %%
type(2j)
# Out:
# complex

# %% [markdown]
# ### Strings

# %%
"String 1"
# Out:
# 'String 1'

# %%
"String 1 " + "String 2" # Concatination
# Out:
# 'String 1 String 2'

# %%
"1" + "1"
# Out:
# '11'

# %%
1 + "1"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 1 + "1"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ### Booleans

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
1 == 1 # '==' used for comparison. '=' used for assignement
# Out:
# True

# %%
1 == 2
# Out:
# False
