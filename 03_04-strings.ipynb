# %%
import math

# %% [markdown]
# # Strings

# %% [markdown]
# ## Slicing

# %%
name = 'My name is Ryan Mitchell'

# %%
name[0]
# Out:
# 'M'

# %%
name[1]
# Out:
# 'y'

# %%
name[0:7] # get first 7 chars, :7 7 not included
# Out:
# 'My name'

# %%
name[:7]
# Out:
# 'My name'

# %%
name[11:] # from index 11 to the end
# Out:
# 'Ryan Mitchell'

# %%
myList = [1,2,3,4,5]

# %%
myList[2:4]
# Out:
# [3, 4]

# %%
len(name)
# Out:
# 24

# %%
len(myList)
# Out:
# 5

# %% [markdown]
# ## Formatting

# %%
'My number is: '+ 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 'My number is: '+ 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
'My number is: '+str(5)
# Out:
# 'My number is: 5'

# %%
f'My number is: {5}'
# Out:
# 'My number is: 5'

# %%
f'My number is: {5} and twice that is {2*5}'
# Out:
# 'My number is: 5 and twice that is 10'

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
f'Pi is: {math.pi:.2f}'
# Out:
# 'Pi is: 3.14'

# %%
'Pi is: {}'.format(math.pi)
# Out:
# 'Pi is: 3.141592653589793'

# %% [markdown]
# ## Multi-line Strings

# %%
myString = '''
Here is a long block of text
I can add newlines!
the text doesn't stop until it sees \'\'\'

'''

# %%
myString
# Out:
# "\nHere is a long block of text\nI can add newlines!\nthe text doesn't stop until it sees '''\n\n"

# %%
print(myString)
# Out:
# Here is a long block of text
# I can add newlines!
# the text doesn't stop until it sees '''
