# %%
from collections import defaultdict

# %% [markdown]
# # Dictionaries

# %%
animals = {
    'a': 'aardvark',
    'b': 'bear',
    'c': 'cat',
}
animals
# Out:
# {'a': 'aardvark', 'b': 'bear', 'c': 'cat'}

# %%
animals['a']
# Out:
# 'aardvark'

# %%
animals['d'] = 'dog'

# %%
animals
# Out:
# {'a': 'aardvark', 'b': 'bear', 'c': 'cat', 'd': 'dog'}

# %%
animals['a'] = 'antelope'
animals
# Out:
# {'a': 'antelope', 'b': 'bear', 'c': 'cat', 'd': 'dog'}

# %%
animals.keys() # get dictionary key
# Out:
# dict_keys(['a', 'b', 'c', 'd'])

# %%
animals.values() # get diconary values

# %%
list(animals.keys())
# Out:
# ['a', 'b', 'c', 'd']

# %%
animals['e'] # null index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 animals['e'] # null index
#
# KeyError: 'e'

# %%
animals.get('a') # same as animals['a']
# Out:
# 'antelope'

# %%
len(animals)
# Out:
# 4

# %%
animals = {
    'a': ['aardvark', 'antelope'],
    'b': ['bear'],
}

# %%
animals
# Out:
# {'a': ['aardvark', 'antelope'], 'b': ['bear']}

# %%
animals['b'].append('bison')

# %%
animals
# Out:
# {'a': ['aardvark', 'antelope'], 'b': ['bear', 'bison']}

# %%
animals['c'] = ['cat']

# %%
animals
# Out:
# {'a': ['aardvark', 'antelope'], 'b': ['bear', 'bison'], 'c': ['cat']}

# %%
if 'c' not in animals:
    animals['c'] = []
    
animals['c'].append('cat')

# %%
animals
# Out:
# {'a': ['aardvark', 'antelope'], 'b': ['bear', 'bison'], 'c': ['cat', 'cat']}

# %% [markdown]
# ## The Default Dict

# %%
animals = defaultdict(list)

# %%
animals
# Out:
# defaultdict(list, {})

# %%
animals['e'].append('elephant')
animals
# Out:
# defaultdict(list, {'e': ['elephant']})

# %%
animals['e'].append('emu')
animals
# Out:
# defaultdict(list, {'e': ['elephant', 'emu']})

# %%
animals['f']
# Out:
# []
