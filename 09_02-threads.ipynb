# %%
import threading
import time

# %% [markdown]
# # Threads

# %%
def longSquare(num):
    time.sleep(1)
    return num**2

[longSquare(n) for n in range(0, 5)]
# Out:
# [0, 1, 4, 9, 16]

# %%
t1 = threading.Thread(target=longSquare, args=(1,))
t2 = threading.Thread(target=longSquare, args=(2,))

t1.start()
t2.start()

t1.join()
t2.join()

# %%
def longSquare(num, results):
    time.sleep(1)
    results[num] = num**2

results = {}
t1 = threading.Thread(target=longSquare, args=(1,results))
t2 = threading.Thread(target=longSquare, args=(2,results))

t1.start()
t2.start()

t1.join()
t2.join()

print(results)
# Out:
# {2: 4, 1: 1}

# %%
def longSquare(num, results):
    time.sleep(1)
    results[num] = num**2

results = {}
threads = [threading.Thread(target=longSquare, args=(n, results)) for n in range(0, 100)]
[t.start() for t in threads]
[t.join() for t in threads]
print(results)
# Out:
# {9: 81, 12: 144, 16: 256, 18: 324, 14: 196, 1: 1, 2: 4, 20: 400, 4: 16, 29: 841, 17: 289, 0: 0, 7: 49, 10: 100, 11: 121, 8: 64, 30: 900, 32: 1024, 31: 961, 5: 25, 19: 361, 13: 169, 33: 1089, 6: 36, 3: 9, 23: 529, 15: 225, 21: 441, 26: 676, 37: 1369, 41: 1681, 51: 2601, 84: 7056, 24: 576, 36: 1296, 38: 1444, 39: 1521, 27: 729, 22: 484, 42: 1764, 43: 1849, 25: 625, 44: 1936, 45: 2025, 46: 2116, 48: 2304, 49: 2401, 28: 784, 52: 2704, 53: 2809, 54: 2916, 40: 1600, 55: 3025, 56: 3136, 59: 3481, 60: 3600, 63: 3969, 64: 4096, 65: 4225, 62: 3844, 66: 4356, 67: 4489, 68: 4624, 69: 4761, 70: 4900, 71: 5041, 34: 1156, 72: 5184, 73: 5329, 74: 5476, 50: 2500, 75: 5625, 76: 5776, 77: 5929, 79: 6241, 78: 6084, 81: 6561, 80: 6400, 82: 6724, 57: 3249, 58: 3364, 35: 1225, 61: 3721, 47: 2209, 83: 6889, 86: 7396, 87: 7569, 88: 7744, 85: 7225, 89: 7921, 90: 8100, 91: 8281, 93: 8649, 92: 8464, 95: 9025, 94: 8836, 96: 9216, 98: 9604, 97: 9409, 99: 9801}
