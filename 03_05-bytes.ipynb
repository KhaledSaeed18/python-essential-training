# %% [markdown]
# # Bytes

# %%
bytes(4) # crate empty bytes object 4 bytes long
# Out:
# b'\x00\x00\x00\x00'

# %% [markdown]
# x00 => hexadecimal (base16) - 256 possibilities = 2^8

# %% [markdown]
# 1 byte = 8 bits => 4 bytes = 32 bits

# %%
smileyBytes = bytes('🙄', 'utf-8')
smileyBytes
# Out:
# b'\xf0\x9f\x99\x84'

# %%
smileyBytes.decode('utf-8')
# Out:
# '🙄'

# %%
smileyBytes = bytearray('🙄', 'utf-8')

# %%
smileyBytes
# Out:
# bytearray(b'\xf0\x9f\x99\x84')

# %%
smileyBytes[3] = int('85', 16)

# %%
smileyBytes.decode('utf-8')
# Out:
# '🙅'
