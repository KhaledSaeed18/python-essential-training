# %%
import time

# %% [markdown]
# # Handling Exceptions

# %% [markdown]
# ## Try / Except

# %%
def causeError():
    try:
        return 1/0
    except Exception as e:
        return e
    
causeError()
# Out:
# ZeroDivisionError('division by zero')

# %%
def causeError():
    try:
        return 1/0
    except Exception:
        print('There was some sort of error!')
    
causeError()
# Out:
# There was some sort of error!

# %% [markdown]
# ## Finally

# %%
def causeError():
    try:
        return 1/0
    except Exception:
        print('There was some sort of error!')
    finally: # always run
        print('This will always execute!')
    
causeError()
# Out:
# There was some sort of error!
# This will always execute!

# %%
def causeError():
    start = time.time()
    try:
        time.sleep(0.5)
        return 1/0
    except Exception:
        print('There was some sort of error!')
    finally:
        print(f'Function took {time.time() - start} seconds to execute')
    
causeError()
# Out:
# There was some sort of error!
# Function took 0.5050849914550781 seconds to execute

# %% [markdown]
# ## Catching Exceptions by Type

# %%
def causeError():
    try:
        return 1 + 'a'

    except TypeError:
        print('There was a type error!')
    except ZeroDivisionError:
        print('There was a zero division error!')
    except Exception:
        print('There was some sort of error!')

    
causeError()
# Out:
# There was a type error!

# %% [markdown]
# ## Custom Decorators

# %%
def handleException(func):
    def wrapper(*args):
        try:
            func(*args)
        except TypeError:
            print('There was a type error!')
        except ZeroDivisionError:
            print('There was a zero division error!')
        except Exception:
            print('There was some sort of error!')
    return wrapper

@handleException
def causeError():
    return 1/0

causeError()
# Out:
# There was a zero division error!

# %% [markdown]
# ## Raising Exceptions

# %%
@handleException
def raiseError(n):
    if n == 0:
        raise Exception()
    print(n)
    
raiseError(1)
# Out:
# 1

# %%
raiseError(0)
# Out:
# There was some sort of error!
