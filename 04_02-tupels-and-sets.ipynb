# %% [markdown]
# # Sets

# %%
mySet = {'a', 'b', 'c'}
mySet
# Out:
# {'a', 'b', 'c'}

# %%
mySet = set(('a', 'b', 'c')) # use the set class

# %%
mySet = set(['a', 'b', 'c']) # use the set class

# %%
mySet
# Out:
# {'a', 'b', 'c'}

# %%
myList = ['a', 'b', 'b', 'c', 'c']
myList = list(set(myList)) # remove list duplicates
myList
# Out:
# ['b', 'a', 'c']

# %%
mySet[0] # not orderd
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 mySet[0] # not orderd
#
# TypeError: 'set' object is not subscriptable

# %%
number = 1
1[0]
# Out:
# <>:2: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# /var/folders/n5/xjb5bs6x26j1fhhvc6m90pf80000gn/T/ipykernel_2713/2203923273.py:2: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
#   1[0]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 number = 1
# ----> 2 1[0]
#
# TypeError: 'int' object is not subscriptable

# %%
mySet.add('d')
mySet
# Out:
# {'a', 'b', 'c', 'd'}

# %%
'a' in mySet
# Out:
# True

# %%
'z' in mySet
# Out:
# False

# %%
len(mySet)
# Out:
# 4

# %%
while len(mySet):
    print(mySet.pop())
# Out:
# b
# d
# a
# c

# %%
mySet
# Out:
# set()

# %%
mySet = {'a', 'b', 'c'}
mySet
# Out:
# {'a', 'b', 'c'}

# %%
mySet.discard('a')

# %%
mySet
# Out:
# {'b', 'c'}

# %% [markdown]
# ---

# %% [markdown]
# # Tupels

# %%
myTuple = ('a', 'b', 'c')
myTuple
# Out:
# ('a', 'b', 'c')

# %%
myTuple[0]
# Out:
# 'a'

# %%
myTuple[0] = 'd'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 myTuple[0] = 'd'
#
# TypeError: 'tuple' object does not support item assignment

# %%
myTuple.append(d)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 myTuple.append(d)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
myTuple.add(d)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 myTuple.add(d)
#
# AttributeError: 'tuple' object has no attribute 'add'

# %% [markdown]
# we cannot add items to `tuple`

# %%
def returnsMultipleValues():
    return 1,2,3

type(returnsMultipleValues())
# Out:
# tuple

# %%
myTuple = (1,2,3)

# %%
type(myTuple)
# Out:
# tuple

# %%
myTuple = 1,2,3

# %%
type(myTuple)
# Out:
# tuple

# %%
a, b, c = returnsMultipleValues()

# %%
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3
