# %% [markdown]
# # Errors and Exceptions

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
def causeError():
    return 1/0

causeError()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 def causeError():
#       2     return 1/0
# ----> 4 causeError()
#
# Cell In[2], line 2, in causeError()
#       1 def causeError():
# ----> 2     return 1/0
#
# ZeroDivisionError: division by zero

# %%
def causeError():
    return 1/0 # 1

def callCauseError():
    return causeError() # 2 

callCauseError() # 3
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 7
#       4 def callCauseError():
#       5     return causeError() # 2
# ----> 7 callCauseError() # 3
#
# Cell In[3], line 5, in callCauseError()
#       4 def callCauseError():
# ----> 5     return causeError()
#
# Cell In[3], line 2, in causeError()
#       1 def causeError():
# ----> 2     return 1/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Try / Except

# %%
try:
    1/0
except Exception as e: # if an errro happens in the try block we catch it here
    print(type(e))
# Out:
# <class 'ZeroDivisionError'>
